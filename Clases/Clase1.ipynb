# %% [markdown]
# # Notas de Clase 1

# %% [markdown]
# ## Programas a Instalar:
#
# - Carta
# - ds9
# - Crpurcell
# - CASA (NRAO)
#
#
# ## Tareas
#
# - Investigar los tipos de Radiotelescopios que existen (tipos y ubicación)
# - Descargar los programas
# -
